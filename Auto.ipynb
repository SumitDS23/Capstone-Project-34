# %%
import pandas as pd 
import datetime as dt 
from pandas_datareader import data as pdr

# %%
import yfinance as yf
yf.pdr_override()

# %%
end_test = dt.datetime.now()
start_test=dt.datetime(2022,7,1)
end_test
# Out:
# datetime.datetime(2023, 8, 16, 22, 34, 37, 174499)

# %%
end_train=dt.datetime(2022,6,30)
start_train=dt.datetime(2019,7,1)

# %%
stocklist=['M&M','MARUTI','TATAMOTORS','BAJAJ-AUTO','EICHERMOT','HEROMOTOCO','TIINDIA','TVSMOTOR','ASHOKLEY','BHARATFORG']
stocks=[i + '.NS' for i in stocklist]
stocks
# Out:
# ['M&M.NS',
#  'MARUTI.NS',
#  'TATAMOTORS.NS',
#  'BAJAJ-AUTO.NS',
#  'EICHERMOT.NS',
#  'HEROMOTOCO.NS',
#  'TIINDIA.NS',
#  'TVSMOTOR.NS',
#  'ASHOKLEY.NS',
#  'BHARATFORG.NS']

# %%
df=pdr.get_data_yahoo(stocks,"2022-07-1","2023-08-16")
df.head(100)
# Out:
# [*********************100%%**********************]  10 of 10 completed
#              Adj Close                                                         \
#            ASHOKLEY.NS BAJAJ-AUTO.NS BHARATFORG.NS EICHERMOT.NS HEROMOTOCO.NS
# Date
# 2022-07-01  140.740738   3408.165771    634.989075  2734.223633   2597.195557
# 2022-07-04  139.538223   3460.022461    638.528931  2747.585938   2594.047363
# 2022-07-05  139.297729   3462.843506    646.591614  2756.625488   2572.246094
# 2022-07-06  141.366028   3547.751465    645.510010  2857.188965   2661.096680
# 2022-07-07  142.376129   3568.860840    653.720215  2892.805908   2668.285156
# ...                ...           ...           ...          ...           ...
# 2022-11-21  139.212341   3403.370361    820.073486  3341.715820   2580.347412
# 2022-11-22  139.599869   3402.994141    832.123962  3338.204590   2588.057129
# 2022-11-23  140.907700   3392.416016    837.082947  3343.990479   2562.422119
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2022-07-01', '2022-07-04', '2022-07-05', '2022-07-06',
#                '2022-07-07', '2022-07-08', '2022-07-11', '2022-07-12',
#                '2022-07-13', '2022-07-14',
#                ...
#                '2023-08-01', '2023-08-02', '2023-08-03', '2023-08-04',
#                '2023-08-07', '2023-08-08', '2023-08-09', '2023-08-10',
#                '2023-08-11', '2023-08-14'],
#               dtype='datetime64[ns]', name='Date', length=278, freq=None)

# %%
df.columns
# Out:
# MultiIndex([('Adj Close',   'ASHOKLEY.NS'),
#             ('Adj Close', 'BAJAJ-AUTO.NS'),
#             ('Adj Close', 'BHARATFORG.NS'),
#             ('Adj Close',  'EICHERMOT.NS'),
#             ('Adj Close', 'HEROMOTOCO.NS'),
#             ('Adj Close',        'M&M.NS'),
#             ('Adj Close',     'MARUTI.NS'),
#             ('Adj Close', 'TATAMOTORS.NS'),
#             ('Adj Close',    'TIINDIA.NS'),
#             ('Adj Close',   'TVSMOTOR.NS'),
#             (    'Close',   'ASHOKLEY.NS'),
#             (    'Close', 'BAJAJ-AUTO.NS'),
#             (    'Close', 'BHARATFORG.NS'),
#             (    'Close',  'EICHERMOT.NS'),
#             (    'Close', 'HEROMOTOCO.NS'),
#             (    'Close',        'M&M.NS'),
#             (    'Close',     'MARUTI.NS'),
#             (    'Close', 'TATAMOTORS.NS'),
#             (    'Close',    'TIINDIA.NS'),
#             (    'Close',   'TVSMOTOR.NS'),
#             (     'High',   'ASHOKLEY.NS'),
# ...
